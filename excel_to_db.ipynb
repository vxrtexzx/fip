# %%
import pandas as pd
import sqlite3

# File paths
excel_file = '/Users/nt/fip_backend_integration/data_psychologists/database_psychologist.xlsx'  # Replace with your Excel file path
sqlite_db = 'psychologists.db'     # Name of the SQLite database

# Connect to SQLite database
conn = sqlite3.connect(sqlite_db)
cursor = conn.cursor()

df = pd.read_excel(excel_file)
df
# Out:
#     id                           full_name  \
# 0    1                     Наталья Павлова
# 1    2          Суйунбаева Асель Таласовна
# 2    3           Чибышева Ирина Алексеевна
# 3    4                 Мед центр «Евромед»
# 4    5                              Айгуль
# 5    6                            Гульмира
# 6    7                                Олег
# 7    8                               Ольга
# 8    9                                 Шер
# 9   10                         Рыскуль эже
# 10  11                            Салтанат
# 11  12                   Гульмира Апышевна
# 12  13   Базарбаева Гульмира Кадыракуновна
# 13  14        Бровкина Светлана Николаевна
# 14  15  Кабылбекова Гульмира Кадыракуновна
# 15  16               Рустам кызы Бакыткуль
# 16  17          Файзулина Зарина Тимуровна
# 17  18            Федорова Людмила Юрьевна
# 18  19             Кризисный центр «Сезим»
# 19  20                     Виктория Попова
# 20  21                              Чолпон
# ...

# %%
import pandas as pd
import sqlite3

# File path to the SQLite database
sqlite_db = 'psychologists.db'  # Replace with your SQLite database file

# Connect to the SQLite database
conn = sqlite3.connect(sqlite_db)

# Query the database and load the result into a DataFrame
# Replace 'table_name' with the name of your table
query = "SELECT name FROM sqlite_master WHERE type='table';"
query1 = "SELECT * FROM Sheet1"

df = pd.read_sql_query(query1, conn)

# Display the DataFrame
print(df)

# Close the connection
conn.close()
# Out:
#     id                           full_name  \
# 0    1                     Наталья Павлова
# 1    2          Суйунбаева Асель Таласовна
# 2    3           Чибышева Ирина Алексеевна
# 3    4                 Мед центр «Евромед»
# 4    5                              Айгуль
# 5    6                            Гульмира
# 6    7                                Олег
# 7    8                               Ольга
# 8    9                                 Шер
# 9   10                         Рыскуль эже
# 10  11                            Салтанат
# 11  12                   Гульмира Апышевна
# 12  13   Базарбаева Гульмира Кадыракуновна
# 13  14        Бровкина Светлана Николаевна
# 14  15  Кабылбекова Гульмира Кадыракуновна
# 15  16               Рустам кызы Бакыткуль
# 16  17          Файзулина Зарина Тимуровна
# 17  18            Федорова Людмила Юрьевна
# 18  19             Кризисный центр «Сезим»
# 19  20                     Виктория Попова
# 20  21                              Чолпон
# ...
